# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51853/2303a51853ADM/blob/main/Customer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/Mall_Customers.csv')
print(df.head())

print(df.isnull().sum())
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40
# CustomerID            0
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_normalize=['Age']
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
df[columns_to_normalize].head()
# Out:
#         Age
# 0  0.019231
# 1  0.057692
# 2  0.038462
# 3  0.096154
# 4  0.250000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
df[columns_to_normalize].head()
# Out:
#         Age
# 0 -1.424569
# 1 -1.281035
# 2 -1.352802
# 3 -1.137502
# 4 -0.563369
